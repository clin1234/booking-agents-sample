# %%
# import pandas as pd
from datetime import datetime, timedelta
from pymongo import MongoClient, UpdateOne
import json
import os
from dotenv import load_dotenv

# %%
# uncomment to use env file
# load_dotenv("variables.env", override=True)
load_dotenv(override=True)

DOCUMENTDB_CONNECTION_STRING = os.getenv("DOCUMENTDB_CONNECTION_STRING")
COLLECTION_NAME = os.getenv("COLLECTION_NAME") if os.getenv("COLLECTION_NAME") else "listings"
DATABASE_NAME = os.getenv("DATABASE_NAME") if os.getenv("DATABASE_NAME") else "contoso_bookings"
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
OPENAI_EMBEDDING_MODEL = os.getenv("OPENAI_EMBEDDING_MODEL", "text-embedding-3-small")
OPENAI_CHAT_MODEL = os.getenv("OPENAI_CHAT_MODEL", "gpt-3.5-turbo")

print(OPENAI_API_KEY)
# Out:
# a9c67fe3987f44e3a5438e551c33d9db

# %%
mongo_client = MongoClient(DOCUMENTDB_CONNECTION_STRING)

db = mongo_client[DATABASE_NAME]
collection = db[COLLECTION_NAME]

if COLLECTION_NAME not in db.list_collection_names():
    db.create_collection(COLLECTION_NAME)
    print("Created collection '{}'.\n".format(COLLECTION_NAME))
else:
    print("Using collection: '{}'.\n".format(COLLECTION_NAME))
# Out:
# Using collection: 'listings'.

# %%
# Create geospatial index for location-based queries
db.command({
  'createIndexes': 'listings',
  'indexes': [
    {
      'name': 'location_2dsphere',
      'key': {
        "location": "2dsphere"
      }
    }
  ]
})

# Create index on amenities for faster filtering
collection.create_index('amenities')

print("Indexes created successfully")
# Out:
# {'raw': {'defaultShard': {'numIndexesBefore': 4,
#    'numIndexesAfter': 4,
#    'createdCollectionAutomatically': False,
#    'note': 'all indexes already exist',
#    'ok': 1}},
#  'ok': 1}

# %%
# Load JSON data from file
with open("data/datasets without embeddings/small_for_testing.json", 'r') as file:
    data = json.load(file)

print(data[0])
# Out:
# {'id': '360', 'listing_url': 'https://www.airbnb.com/rooms/360', 'source': 'city scrape', 'name': 'Sit in the Peaceful Garden of the Chickadee Cottage in LoHi', 'description': "Enjoy the famous Colorado weather and unplug in indoor & outdoor living. <br />Our charming cottage has a serene ambiance throughout every area. <br />Spend a sunny afternoon out on the hammock or enjoy the garden parlor sofa relax, read, or play a game, sink into the shared hot tub, practice yoga on the deck.<br />We are located next to downtown and in the neighborhood of lower highlands, <br />Short walks to superb coffee shops, restaurants, microbrews, distilleries, dispensaries & downtown. We are 420 outdoors only. LGBT Friendly, allergy-free, fragrance-free & pet-free. Ozone sterilized.<br /><br />Chickadee Cottage is the largest of our guest cottages.<br /><br />LOCATION: <br />The cottage is located in the center of Lower Highlands (LOHI) next to the Navajo Street Arts District along with the Bug Theater. Check out the Bugs listing to see what's going on - plays/film/comedy nights. No need to cab it because we are in the midst of it all.<br /><br />COTTAGE DESCRIPTION: <br /><br", 'neighborhood_overview': 'The cottage is located in the center of Lower Highlands (LOHI) next to the Navajo Street Arts District. Catch a show at the iconic Bug Theater. Wandering the neighborhood to discover breweries, distilleries and bars for local drinks, tuck into a family owned taqueria or explore more formal dinning experience. We are a vibrant neighborhood in Denver where you can see and do but just a quick walk thru the park to downtown, or a mile drive to RiNo. We are just 2.5 mile walk or dirve to Meow Wolf.', 'latitude': '39.766414642333984', 'longitude': '-105.0020980834961', 'price': '$161.00', 'amenities': '["Hangers", "Essentials", "Dedicated workspace", "Microwave", "Shampoo", "Hair dryer", "Oven", "Stainless steel gas stove", "Dishes and silverware", "Single level home", "Shared backyard \\u2013 Fully fenced", "Self check-in", "Smoke alarm", "Board games", "Hammock", "First aid kit", "Body soap", "Carbon monoxide alarm", "Fire extinguisher", "Luggage dropoff allowed", "Outdoor dining area", "Shared patio or balcony", "Heating", "Kitchen", "Fire pit", "Refrigerator", "Cooking basics", "Shared hot tub", "Extra pillows and blankets", "TV with Hulu, HBO Max, Netflix, Roku", "BBQ grill", "Free washer \\u2013 In unit", "Courtyard view", "Central air conditioning", "Ceiling fan", "Free street parking", "Long term stays allowed", "Room-darkening shades", "Coffee maker: espresso machine", "Outdoor furniture", "Iron", "Hot water kettle", "Keypad", "Wifi \\u2013 36 Mbps", "Bed linens", "Exterior security cameras on property", "Free dryer \\u2013 In unit", "Bathtub"]', 'beds': '2', 'bedrooms': '2', 'bathrooms': '1.0', 'bathrooms_text': '1 bath', 'property_type': 'Entire guesthouse', 'room_type': 'Entire home/apt', 'host_about': 'We are artists and tinkerers.\n \nWe enjoy many activities here in Denver -  cooking, growing fruits and vegetables are some that we get to do here at the cottages along with mixed media projects and furniture building. \n\nWe are always up to some new outdoor project when the Colorado weather permits and hunker down inside by the fire in the winter keeping our hands busy with knitting, card making or some other project we can dream up.   In fact the most recent outdoor project is for an outdoor parlor that will be winter friendly. \n\nGiovanni and I have grown in our collaborations and embrace our age and abilities  for self governance in employment - Giovanni had moved into documentaries and I have been spending more time in the commercial film community. \n\nWe have been in the lower highlands for over a decade now and have marveled in the changing landscape and exciting times for new restaurants, breweries and galleries.  We still love to take advantage of the great walks thru the neighborhood and down by the river as often as we can.  ...

# %%
import time
from openai import OpenAI

# Initialize OpenAI client
openai_client = OpenAI(api_key=OPENAI_API_KEY)

batch_size = 15
total_updated = 0
iteration = 0

def generate_embedding(text):
    """Generate embedding for text using OpenAI"""
    response = openai_client.embeddings.create(
        input=text,
        model=OPENAI_EMBEDDING_MODEL
    )
    return response.data[0].embedding

while True:
    iteration += 1

    # Find records to update
    records_to_update = collection.find({
        '$and': [
            {'embeddings': {'$exists': False}},
            {'description': {'$exists': True}}
        ]
    }).limit(batch_size)

    records_to_update = list(records_to_update)

    if not records_to_update:
        print(f"All rows have been updated. Total updated rows: {total_updated}")
        break

    total_updated += len(records_to_update)
    print(f"Iteration: {iteration}, has handled {total_updated} rows")

    # Prepare bulk operations
    bulk_ops = []
    for record in records_to_update:
        # Combine text fields for embedding
        text_to_embed = ' '.join(filter(None, [
            record.get('name', ''),
            record.get('description', ''),
            record.get('neighborhood_overview', '')
        ]))
        
        # Generate embedding
        embedding = generate_embedding(text_to_embed)
        
        # Create update operation
        bulk_ops.append(
            UpdateOne(
                {'_id': record['_id']},
                {'$set': {'embeddings': embedding}}
            )
        )

    if bulk_ops:
        result = collection.bulk_write(bulk_ops)
        print(f"Bulk write result: Modified {result.modified_count} documents")

    time.sleep(0.5)  # Sleep to avoid rate limits
# Out:
# [{'_id': ObjectId('67252c67739892c59d79506b'), 'id': '35764557', 'listing_url': 'https://www.airbnb.com/rooms/35764557', 'source': 'city scrape', 'name': 'Sunny Private Apartment Near RiNo', 'description': 'This newer private 1br apartment sits above the garage behind host residence, is centrally located in a residential neighborhood northeast of downtown, and 5-10 minute driving distance from LoDo, RiNo, breweries, downtown, & other shopping, dining, & entertainment; City Park, Zoo, & museums. Enjoy your own space with all the amenities, free off-street parking, & shared back yard & patio with plenty of seating for relaxing & dining. (For groups over 4, we have a room on a separate listing.)', 'neighborhood_overview': 'The Cole neighborhood is a diverse residential neighborhood next to the popular RiNo district, which is more industrial but changing quickly. You may notice construction in and around the neighborhoods as Denver is growing very rapidly and we have several big projects underway, including a highway expansion. <br /><br />We are easy driving/biking distance to other neighborhoods, a lot of new restaurants, shops, art galleries, breweries, dispensaries, and music venues--notably the Mission Ballroom, which opened August 2019. Easily accessible via main streets and highways. <br /><br />Many homes in our neighborhood were built in the early 1900s. The closest neighborhood bars you can walk to are NOLA and Clove Pizzeria, and Cohesion brewery; the closest coffee shop is Rivers and Roads. Also nearby are the Whittier Cafe, Crema, and Prodigy. <br /><br />The trendy "RiNo" neighborhood, next door to Cole, is a craft beer mecca, and growing. You will find lots of new businesses and places to e', 'latitude': '39.768182310721784', 'longitude': '-104.95921072434753', 'price': '$116.00', 'amenities': ['Free driveway parking on premises – 1 space', 'Hangers', 'Essentials', 'Dishwasher', 'Dedicated workspace', 'Toaster', 'Barbecue utensils', 'Microwave', 'Shampoo', 'Hair dryer', 'Baking sheet', 'Dishes and silverware', 'Ethernet connection', 'Shared backyard – Fully fenced', 'Self check-in', 'Smoke alarm', 'Dining table', 'Blender', 'Fast wifi – 93 Mbps', 'Board games', 'Samsung stainless steel electric stove', 'Freezer', 'Heating - split type ductless system', 'Mountain view', 'First aid kit', 'Body soap', 'Portable heater', 'Shower gel', 'Carbon monoxide alarm', 'Fire extinguisher', 'Wine glasses', 'Luggage dropoff allowed', 'Outdoor dining area', 'Cleaning products', '32 inch HDTV with Hulu, DVD player', 'Shared patio or balcony', 'Kitchen', 'Refrigerator', 'Cooking basics', 'Private BBQ grill: electric', 'Extra pillows and blankets', 'Hot water', 'Drying rack for clothing', 'Clothing storage: closet', 'Free washer – In unit', 'AC - split type ductless system', 'Stainless steel oven', 'Coffee maker', 'Laundromat nearby', 'Free street parking', 'Ceiling fan', 'Long term stays allowed', 'Garden view', 'Room-darkening shades', 'Conditioner', 'Outdoor furniture', 'Iron', 'Hot water kettle', 'Indoor fireplace: electric', 'Keypad', 'Private entrance', 'Bed linens', 'Free dryer – In unit'], 'beds': '2', 'bedrooms': '1', 'bathrooms': '1.0', 'bathrooms_text': '1 bath', 'property_type': 'Entire guesthouse', 'room_type': 'Entire home/apt', 'host_about': "Eric and I are both Illinois natives but Denver is our home. We started hosting Airbnb guests in 2016, and it's been a great experience. We've met people from all over the world, and are excited to share the best parts of Denver with our guests. I sold my IT consulting business in 2022, and now work as a coach and other side projects. Eric is an artist, and also works in the beer industry. We host events at our home which we share via @yorkstbnb.", 'data_to_embed': 'Sunny Private Apartment Near RiNo This newer private 1br apartment sits above the garage behind host residence, is centrally located in a residential neighborhood northeast of downtown, and 5-10 minute driving distance f ...
# Iteration: 1, has handled 100 rows
# Bulk write result: {'writeErrors': [], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 0, 'nMatched': 100, 'nModified': 100, 'nRemoved': 0, 'upserted': []}
# [{'_id': ObjectId('67252c67739892c59d7950cf'), 'id': '38552880', 'listing_url': 'https://www.airbnb.com/rooms/38552880', 'source': 'city scrape', 'name': 'Very Large one bedroom and bath in nice home.', 'description': 'Very large bedroom and bath. Home completly remodeled in 2016. Great neighborhood close to DU, Cherry Creek North, Downtown.', 'neighborhood_overview': '', 'latitude': '39.66889', 'longitude': '-104.94405', 'price': '$55.00', 'amenities': ['Hangers', 'Essentials', 'Dedicated workspace', 'Microwave', 'Shampoo', 'Hair dryer', 'Dishes and silverware', 'Air conditioning', 'Smoke alarm', 'First aid kit', 'Carbon monoxide alarm', 'Fire extinguisher', 'Washer', 'Pets allowed', 'Outdoor dining area', 'Heating', 'Kitchen', 'Refrigerator', 'Cooking basics', 'Hot water', 'BBQ grill', 'Lock on bedroom door', 'Dryer', 'Free street parking', 'Outdoor furniture', 'Free parking on premises', 'Private living room', 'Wifi', 'TV'], 'beds': '1', 'bedrooms': '1', 'bathrooms': '1.0', 'bathrooms_text': '1 private bath', 'property_type': 'Private room in home', 'room_type': 'Private room', 'host_about': '', 'data_to_embed': 'Very Large one bedroom and bath in nice home. Very large bedroom and bath. Home completly remodeled in 2016. Great neighborhood close to DU, Cherry Creek North, Downtown. ', 'location': {'type': 'Point', 'coordinates': [-104.94405, 39.66889]}}, {'_id': ObjectId('67252c67739892c59d7950d0'), 'id': '38623073', 'listing_url': 'https://www.airbnb.com/rooms/38623073', 'source': 'city scrape', 'name': 'Congress Park Carriage House', 'description': "Welcome to your cozy carriage house in Denver's popular Congress Park neighborhood.  Perfect for a vacation or business trip.  Our private, fully furnished space offers comfortable amenities with restaurants and coffee shops just steps from the front door.  The space is minutes from Downtown Denver and just a few blocks to many famous Denver sites such as the restaurants and music venues of Colfax, City Park, Cheesman Park, Congress Park and Cherry Creek North neighborhood and shopping mall.", 'neighborhood_overview': "Congress Park is a beautiful, established neighborhood in Denver.  The carriage house is close to so many Denver attractions.  City Park, the Natural History Museum, Denver Zoo,  Denver Botanic Gardens, Cheesman ParkThe Bluebird on Colfax, The Ogden, The Fillmore music venues and the Cherry Creek North shopping district and mall.  With events in these locations throughout the year.  There is a Starbucks, Einsteins Bagel, Falafel King and a few bars just 1 block from the space.  In addition, Snooze and Trader Joe's are just across the street and Tag Burger bar and the cutest ice cream shop are about 5 blocks from the house.", 'latitude': '39.72812', 'longitude': '-104.94131', 'price': '$149.00', 'amenities': ['Hangers', 'Essentials', 'Toaster', 'Dedicated workspace', 'Microwave', 'Shampoo', 'Hair dryer', 'Dishes and silverware', 'Costco  conditioner', 'Self check-in', 'Smoke alarm', 'Freezer', 'Shower gel', 'Fire extinguisher', 'Carbon monoxide alarm', 'Pets allowed', 'Cleaning products', '45 inch HDTV with Roku, premium cable', 'Costco body soap', 'Heating', 'Kitchen', 'Refrigerator', 'Mini fridge', 'Private entrance', 'Cooking basics', 'Extra pillows and blankets', 'Hot water', 'Coffee maker', 'Laundromat nearby', 'Free street parking', 'Long term stays allowed', 'Window AC unit', 'Patio or balcony', 'Room-darkening shades', 'Outdoor furniture', 'Keypad', 'Coffee', 'Wifi', 'Bed linens'], 'beds': '4', 'bedrooms': '0', 'bathrooms': '1.0', 'bathrooms_text': '1 bath', 'property_type': 'Entire home', 'room_type': 'Entire home/apt', 'host_about': "We are two Denver thirty-somethings enjoying the Mile High life with our very friendly chocolate lab/aussie shepherd named Charley and shihtzu mix named Nesta.  When we're not checking out live music or on an adventure in the Rocky Mountains, we love traveling just like you!", 'data_to_embed': "Congress Park Carriage House W ...
# Iteration: 2, has handled 200 rows
# Bulk write result: {'writeErrors': [], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 0, 'nMatched': 100, 'nModified': 100, 'nRemoved': 0, 'upserted': []}
# [{'_id': ObjectId('67252c67739892c59d795134'), 'id': '41352454', 'listing_url': 'https://www.airbnb.com/rooms/41352454', 'source': 'previous scrape', 'name': 'Entire Private Suite - Spacious, Clean and Cozy', 'description': 'This space has the best of both worlds. It’s a straight shot to the mountains for some fun outdoor activities such as skiing, camping, and exploring our beautiful scenery. Minutes away from public transportation, parks, hikes, stores, restaurants, downtown, Red Rocks Amphitheater and Broncos Stadium! Super close to the city center. It’s also super close to the major highways making it incredibly easy to pop over to the mountains or any part of the city!', 'neighborhood_overview': 'It’s in a quiet neighborhood on an U-shaped cold-a-sac. Surrounded by other homes.', 'latitude': '39.72053', 'longitude': '-105.05103', 'price': '', 'amenities': ['Hangers', 'Essentials', 'Toaster', 'Dedicated workspace', 'Barbecue utensils', 'Microwave', 'Shampoo', 'Hair dryer', 'Baking sheet', 'Dishes and silverware', 'Air conditioning', 'Self check-in', 'Smoke alarm', 'Dining table', 'Blender', 'Portable fans', 'Freezer', 'First aid kit', 'Body soap', 'Shower gel', 'Carbon monoxide alarm', 'Fire extinguisher', 'Wine glasses', 'Luggage dropoff allowed', 'Pets allowed', 'Outdoor dining area', 'Cleaning products', 'Shared patio or balcony', 'Heating', 'Kitchen', 'Refrigerator', 'Cooking basics', 'Extra pillows and blankets', 'Shared backyard – Not fully fenced', 'Hot water', 'Drying rack for clothing', 'Clothing storage: closet', 'Free washer – In unit', 'Stainless steel oven', 'Coffee maker', 'BBQ grill', 'Induction stove', 'Free street parking', 'Ceiling fan', 'Long term stays allowed', 'Conditioner', 'Outdoor furniture', 'Free parking on premises', 'Iron', 'Hot water kettle', 'Keypad', 'Fast wifi – 61 Mbps', 'Coffee', 'Private entrance', 'Bed linens', 'Free dryer – In unit'], 'beds': '', 'bedrooms': '1', 'bathrooms': '', 'bathrooms_text': '1 bath', 'property_type': 'Entire home', 'room_type': 'Entire home/apt', 'host_about': 'Clean and easy going ', 'data_to_embed': 'Entire Private Suite - Spacious, Clean and Cozy This space has the best of both worlds. It’s a straight shot to the mountains for some fun outdoor activities such as skiing, camping, and exploring our beautiful scenery. Minutes away from public transportation, parks, hikes, stores, restaurants, downtown, Red Rocks Amphitheater and Broncos Stadium! Super close to the city center. It’s also super close to the major highways making it incredibly easy to pop over to the mountains or any part of the city! It’s in a quiet neighborhood on an U-shaped cold-a-sac. Surrounded by other homes.', 'location': {'type': 'Point', 'coordinates': [-105.05103, 39.72053]}}, {'_id': ObjectId('67252c67739892c59d795135'), 'id': '41353091', 'listing_url': 'https://www.airbnb.com/rooms/41353091', 'source': 'previous scrape', 'name': 'Avail Feb 2024 Bungalow in theTenn/Berkeley area', 'description': 'The current Tenant is moving out at the end of January. Available starting February 1st.  We love this safe neighborhood with friendly neighbors creating a fantastic community block. Lush gardens and parks, hip, independently owned shops, art galleries, and restaurants all make the Denver Highland neighborhood an excellent destination for visitors. The neighborhood borders three diverse districts: Highlands Square, Tennyson Street (adjacent to Berkeley), and Lower Highland (LoHi).', 'neighborhood_overview': "Boutiques, wine shops and bookstores, as well as popular restaurants and bars radiate out from Highlands Square on West 32nd Avenue and Lowell Boulevard. LoHi is characterized by a mix of old and ultra-modern architecture, some of the city's most innovative restaurants and bars and incredible views of the Highland Bridge and downtown Denver. <br /><br />And, in the Tennyson Street Cultural District in the adjacent Berkeley neighborhood, you can spend an afternoon browsing antique prints, ph ...
# Iteration: 3, has handled 300 rows
# Bulk write result: {'writeErrors': [], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 0, 'nMatched': 100, 'nModified': 100, 'nRemoved': 0, 'upserted': []}
# [{'_id': ObjectId('67252c67739892c59d795199'), 'id': '43727079', 'listing_url': 'https://www.airbnb.com/rooms/43727079', 'source': 'city scrape', 'name': 'Mint House Denver : Deluxe Apartment', 'description': "Mint House Denver - Downtown Union Station is the perfect place to stay for just about any trip. Walking distance from Union Station, Coors Field, Central Business District and tons of restaurants and breweries. This apartment is located in a luxury style apartment building and has all the features you're looking for with a fully equipped modern stainless steel kitchen, floor to ceiling windows and in unit washer and dryer.", 'neighborhood_overview': 'Denver - Downtown Union Station is located in Denver’s oldest and trendiest neighborhood: LoDo. There is something for everyone in this historic neighborhood. You will be steps away from the city’s best known restaurants, bars and brewpubs. You will also find an abundance of galleries, shops and boutiques. With plenty of attractions and a wide range of businesses from finance to startups, LoDo is enticing to visitors and locals. Here for a sporting event? Coors field, Mile High Stadium and Pepsi Center are minutes away. Take it all in as you will be in the heart of the most vibrant neighborhood in Denver!', 'latitude': '39.75537', 'longitude': '-105.00247', 'price': '$480.00', 'amenities': ['Hangers', 'Essentials', 'Dishwasher', 'Microwave', 'Shampoo', 'Hair dryer', 'Oven', 'Dishes and silverware', 'Air conditioning', 'Self check-in', 'Smoke alarm', 'Smart lock', 'Mountain view', 'First aid kit', 'Shower gel', 'Carbon monoxide alarm', 'Elevator', 'Washer', 'Heating', 'Kitchen', 'Gym', 'Refrigerator', 'Cooking basics', 'Pool', 'Hot water', 'Coffee maker', 'Dryer', 'Long term stays allowed', 'Iron', 'Stove', 'Wifi', 'Bed linens', 'Exterior security cameras on property', 'TV'], 'beds': '3', 'bedrooms': '2', 'bathrooms': '1.0', 'bathrooms_text': '1 bath', 'property_type': 'Entire serviced apartment', 'room_type': 'Entire home/apt', 'host_about': '', 'data_to_embed': "Mint House Denver : Deluxe Apartment Mint House Denver - Downtown Union Station is the perfect place to stay for just about any trip. Walking distance from Union Station, Coors Field, Central Business District and tons of restaurants and breweries. This apartment is located in a luxury style apartment building and has all the features you're looking for with a fully equipped modern stainless steel kitchen, floor to ceiling windows and in unit washer and dryer. Denver - Downtown Union Station is located in Denver’s oldest and trendiest neighborhood: LoDo. There is something for everyone in this historic neighborhood. You will be steps away from the city’s best known restaurants, bars and brewpubs. You will also find an abundance of galleries, shops and boutiques. With plenty of attractions and a wide range of businesses from finance to startups, LoDo is enticing to visitors and locals. Here for a sporting event? Coors field, Mile High Stadium and Pepsi Center are minutes away. Take it all in as you will be in the heart of the most vibrant neighborhood in Denver!", 'location': {'type': 'Point', 'coordinates': [-105.00247, 39.75537]}}, {'_id': ObjectId('67252c67739892c59d79519a'), 'id': '43727098', 'listing_url': 'https://www.airbnb.com/rooms/43727098', 'source': 'city scrape', 'name': 'Mint House Denver : One Bedroom Apartment', 'description': "Mint House Denver - Downtown Union Station is the perfect place to stay for just about any trip. Walking distance from Union Station, Coors Field, Central Business District and tons of restaurants and breweries. This apartment is located in a luxury style apartment building and has all the features you're looking for with a fully equipped modern stainless steel kitchen, floor to ceiling windows and in unit washer and dryer.", 'neighborhood_overview': 'Denver - Downtown Union Station is located in Denver’s oldest and trendiest neighborhood: LoDo. There is something for everyone ...
# Iteration: 4, has handled 334 rows
# Bulk write result: {'writeErrors': [], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 0, 'nMatched': 34, 'nModified': 34, 'nRemoved': 0, 'upserted': []}
# []
# All rows have been updated. Total updated rows: 334

# %%
import numpy as np

# Define the user's location
user_location = [-105.0020980834961, 39.766414642333984]  # User's location (longitude, latitude)

def cosine_similarity(vec1, vec2):
    """Calculate cosine similarity between two vectors"""
    vec1 = np.array(vec1)
    vec2 = np.array(vec2)
    return np.dot(vec1, vec2) / (np.linalg.norm(vec1) * np.linalg.norm(vec2))

def search_listings(query, amenities=["WiFi", "Dishwasher", "Gym"], limit=5):
    """
    Search for listings using semantic search with location and amenity filters
    """
    # Generate embedding for the query
    query_embedding = generate_embedding(query)
    
    # Filter by location and amenities
    filter_query = {
        "$and": [
            {"amenities": {"$in": amenities}},
            {"location": {"$geoWithin": {"$centerSphere": [user_location, 30/3963.2]}}},
            {"embeddings": {"$exists": True}}
        ]
    }
    
    # Get filtered documents
    candidates = list(collection.find(filter_query))
    
    # Calculate similarity scores
    scored_results = []
    for doc in candidates:
        if 'embeddings' in doc and doc['embeddings']:
            similarity = cosine_similarity(query_embedding, doc['embeddings'])
            doc['similarityScore'] = round(similarity, 2)
            scored_results.append(doc)
    
    # Sort by similarity and return top results
    scored_results.sort(key=lambda x: x['similarityScore'], reverse=True)
    results = scored_results[:limit]
    
    # Print and format results
    results_dict = []
    for doc in results:
        print(f"Similarity Score: {doc['similarityScore']}")  
        print(f"id: {doc['_id']}")
        print(f"Name: {doc.get('name', 'N/A')}")  
        print(f"Location: {doc.get('location', 'N/A')}")  
        print(f"Description: {doc.get('description', 'N/A')}")  
        print(f"Neighborhood Overview: {doc.get('neighborhood_overview', 'N/A')}")
        print(f"Price per day: {doc.get('price', 'N/A')}") 
        print(f"Amenities: {doc.get('amenities', 'N/A')}")
        print(f"Listing Url: {doc.get('listing_url', 'N/A')}\n") 
    
        result = {
            "similarityScore": doc['similarityScore'],
            "id": str(doc['_id']),
            "name": doc.get('name', 'N/A'),
            "location": doc.get('location', 'N/A'),
            "description": doc.get('description', 'N/A'),
            "neighborhood_overview": doc.get('neighborhood_overview', 'N/A'),
            "price": doc.get('price', 'N/A'),
            "amenities": doc.get('amenities', 'N/A'),
            "listing_url": doc.get('listing_url', 'N/A')
        }
        results_dict.append(result)
    
    return results_dict

# %%
query = "quiet home with hot tub"

search_listings(query)

# %%
# Create RAG Function
from langchain.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI, OpenAIEmbeddings

# Initialize OpenAI chat model
openai_chat: ChatOpenAI = ChatOpenAI(
    model=OPENAI_CHAT_MODEL,
    api_key=OPENAI_API_KEY,
    temperature=0.7,
)

# Test the chat flow
chat_response = openai_chat.invoke("Tell me a joke")
print(chat_response.content)
# Out:
# Why don't scientists trust atoms? Because they make up everything!

# %%
from typing import List
from bson import ObjectId
from langchain_core.callbacks import CallbackManagerForRetrieverRun
from langchain_core.documents import Document
from langchain_core.retrievers import BaseRetriever

## Custom Retriever

class CustomRetriever(BaseRetriever):
    def _get_relevant_documents(self, query: str, *, run_manager: CallbackManagerForRetrieverRun) -> List[Document]:
        search_results = search_listings(query)
    
        documents = [] # List of Document objects
        for result in search_results:
            document = Document(
                id={result['id']},
                page_content=result['name'],
                metadata=result
            )
            documents.append(document)
        return documents

# %%
query = "quiet house with hot tub"
retriever = CustomRetriever()
# retriever.invoke(query)
# Out:
# Similarity Score: 0.8543511964710722
# id: 67252c67739892c59d794e66
# Name: Sunny Bungalow with Private Hot Tub Near Downtown
# Location: {'type': 'Point', 'coordinates': [-104.94234, 39.7423]}
# Description: This Bungalow-style single-family home is perfect for multi-family parties or roommate situations.  It features 2 full bedrooms plus a loft-style "guest" bedroom, 2 separate kitchens, hardwood floors, theater, covered front porch, natural light, fenced backyard, a hot tub, and a vibrant, hip neighborhood next to City Park and minutes from downtown!  The garden-level bedroom can be closed off into its own studio apartment complete with its own kitchen and bathroom for multifamily parties.
# Neighborhood Overview: The South City Park / Congress Park Neighborhood is home to quiet residential streets bordered by lively entertainment.  Within walking distance from the house are bars, restaurants, breweries, diners, gyms, yoga studios, salons, coffee shops, retail stores, ice cream parlors, liquor stores, fast food, live music venues, museums, parks, a health food supermarket and a zoo!  The Sprouts Farmer's Market (grocery store) is conveniently located 2 blocks from the house, with a liquor store across the street.
# Price per day:
# Amenities: ['Hangers', 'Essentials', 'Dishwasher', 'Dedicated workspace', 'Toaster', 'Barbecue utensils', 'Smoking allowed', 'Microwave', 'Shampoo', 'Hair dryer', 'Oven', 'Baking sheet', 'Dishes and silverware', 'Private hot tub', 'Self check-in', 'Smoke alarm', 'Dining table', '46 inch HDTV with Amazon Prime Video, Netflix, Roku, standard cable', 'Board games', 'Fireplace guards', 'Freezer', 'First aid kit', 'Body soap', 'Carbon monoxide alarm', 'Fire extinguisher', 'Wine glasses', 'Luggage dropoff allowed', 'Outdoor dining area', 'Cleaning products', 'Kitchen', 'Refrigerator', 'Private entrance', 'Clothing storage: walk-in closet, closet, wardrobe, and dresser', 'Cooking basics', 'Extra pillows and blankets', 'Backyard', 'Hot water', 'Coffee maker', 'BBQ grill', 'Free washer – In unit', 'Laundromat nearby', 'Central air conditioning', 'Ceiling fan', 'Window AC unit', 'Free street parking', 'Long term stays allowed', 'Patio or balcony', 'Room-darkening shades', 'Conditioner', 'Outdoor furniture', 'Central heating', 'Iron', 'Hot water kettle', 'Keypad', 'Stove', 'Wifi', 'Bed linens', 'Exterior security cameras on property', 'Free dryer – In unit', 'Bathtub']
# Listing Url: https://www.airbnb.com/rooms/20956686
#
# Similarity Score: 0.8536706479591533
# id: 67252c67739892c59d7950a9
# Name: 1 Bedroom Suite with Hot Tub
# Location: {'type': 'Point', 'coordinates': [-104.93183, 39.75742]}
# Description: A remodeled space in a great Denver neighborhood with a separate and secure keyless entrance.  Just 2 blocks from recently opened café, brew house, wine bar and pizza joint.  If you prefer to stay in, there’s a kitchen, living room, workout space and bath.  Don’t forget you will also have access to the hot tub.  Enjoy a comfortable queen bed and take advantage of the provided coffee to get your day started.  If you have a larger party please inquire about our 2 bedroom suite option.
# Neighborhood Overview:
# Price per day: $117.00
# Amenities: ['Hot tub', 'Hangers', 'Essentials', 'Dishwasher', 'Microwave', 'Shampoo', 'Hair dryer', 'Oven', 'Dishes and silverware', 'Smoke alarm', 'Exercise equipment', 'Carbon monoxide alarm', 'Fire extinguisher', 'Heating', 'Kitchen', 'Gym', 'Refrigerator', 'Private entrance', 'Cooking basics', 'Backyard', 'Hot water', 'Coffee maker', 'Central air conditioning', 'Free street parking', 'Patio or balcony', 'Stainless steel electric stove', 'Iron', 'Wifi', 'Bed linens', 'Exterior security cameras on property', 'TV']
# Listing Url: https://www.airbnb.com/rooms/37567133
#
# Similarity Score: 0.8501666962901957
# id: 67252c67739892c59d7950be
# Name: 2 Bedroom Suite with Hot Tub
# Location: {'type': 'Point', 'coordinates': [-104.93039, 39.7582]}
# Description: A remodeled space in a great Denver neighborhood with a separate and secure keyless entrance.  Just 2 blocks from recently opened café, brew house, wine bar and pizza joint.  If you prefer to stay in, there’s two bedrooms, a kitchen, living room, workout space and bath.  Don’t forget you will also have access to the hot tub.  Enjoy comfortable queen beds and take advantage of the free coffee to get your day started.  If you have a smaller party please inquire about our 1 bedroom suite option.
# Neighborhood Overview:
# Price per day: $191.00
# Amenities: ['Hot tub', 'Hangers', 'Essentials', 'Dishwasher', 'Microwave', 'Shampoo', 'Hair dryer', 'Oven', 'Dishes and silverware', 'Air conditioning', 'Smoke alarm', 'Carbon monoxide alarm', 'Fire extinguisher', 'Heating', 'Kitchen', 'Gym', 'Refrigerator', 'Private entrance', 'TV with standard cable', 'Cooking basics', 'Extra pillows and blankets', 'Backyard', 'Coffee maker', 'Free street parking', 'Iron', 'Stove', 'Wifi', 'Bed linens', 'Exterior security cameras on property']
# Listing Url: https://www.airbnb.com/rooms/38134365
#
# Similarity Score: 0.8419743901414977
# id: 67252c67739892c59d7950c9
# Name: Denver Couples Retreat 2BR, 2 BA Hot Tub Privacy
# Location: {'type': 'Point', 'coordinates': [-104.91975, 39.6578]}
# Description: Denver Tech Center Private 2 BR, 2 BA apt & patio!  New Cedar Spa Room.  Fun couples reunion getaway!  Make The Blue Bear Den your base camp for exploring colorful Colorado! Close to sports & entertainment venues. Private entrance to downstairs king & queen bedrooms. Premium cable, & wifi.  Nice kitchenette with full size fridge, sink, dishwasher, & microwave.  Close to RTD Light Rail, & Starbucks. Ranked #1 Neighborhood in Colorado, just off I-25 & Hampden.  Relaxing hot tub room.
# Neighborhood Overview: Our Holly Hills neighborhood was ranked #1 in entire state of Colorado by the Denver Post.  Beautiful tree lined streets. We offer a lovely fenced yard around your private entrance and a patio for your enjoyment.
# Price per day: $266.00
# Amenities: ['Hangers', 'Essentials', 'Pack ’n play/Travel crib - always at the listing', 'Books and reading material', 'Dishwasher', 'Toaster', 'Barbecue utensils', 'Microwave', 'Shampoo', 'Hair dryer', 'Private backyard – Fully fenced', 'Baking sheet', 'Clothing storage: closet and dresser', 'Dishes and silverware', 'EV charger - level 1', 'Private hot tub', 'Self check-in', 'Noise decibel monitors on property', 'Smoke alarm', 'Blender', 'Portable fans', 'Board games', 'Freezer', 'First aid kit', 'Shower gel', 'Carbon monoxide alarm', 'Fire extinguisher', 'Wine glasses', 'Luggage dropoff allowed', 'Outdoor dining area', 'Cleaning products', 'Suave conditioner', 'Suave body soap', 'Shared patio or balcony', 'Heating', 'Kitchen', 'Fire pit', 'Cleaning available during stay', 'Refrigerator', 'Private entrance', '42 inch HDTV with standard cable', 'Cooking basics', 'Extra pillows and blankets', 'Hot water', 'Coffee maker', 'BBQ grill', 'Free washer – In unit', 'Central air conditioning', 'Free street parking', 'Long term stays allowed', 'Garden view', 'Outdoor furniture', 'Free parking on premises', 'Iron', 'Keypad', 'Indoor fireplace: electric', 'Coffee', 'Folding or convertible high chair', 'Wifi', 'Bed linens', 'Exterior security cameras on property', 'Free dryer – In unit']
# Listing Url: https://www.airbnb.com/rooms/38511409
#
# Similarity Score: 0.8418297673362369
# id: 67252c67739892c59d794e2b
# Name: NEW! 2BR Townhouse, private deck/hot tub/Arcade!
# Location: {'type': 'Point', 'coordinates': [-104.97374, 39.74706]}
# Description:
# Neighborhood Overview: Close to surrounding attractions!
# Price per day: $499.00
# Amenities: ['Hangers', 'Essentials', 'Dishwasher', 'Dedicated workspace', 'Barbecue utensils', 'Microwave', 'Shampoo', 'Hair dryer', 'Oven', 'Dishes and silverware', 'Private hot tub', 'City skyline view', 'Self check-in', 'Smoke alarm', 'Mountain view', 'First aid kit', 'Private patio or balcony', 'Fast wifi – 633 Mbps', 'Carbon monoxide alarm', 'Fire extinguisher', 'Game console', 'Heating', 'Kitchen', 'Refrigerator', 'TV with standard cable', 'Cooking basics', 'Extra pillows and blankets', 'Hot water', 'Coffee maker', 'BBQ grill', 'Free washer – In unit', 'Central air conditioning', 'Free street parking', 'Outdoor furniture', 'Free parking on premises', 'Iron', 'Keypad', 'Stove', 'Private entrance', 'Bed linens', 'Free dryer – In unit']
# Listing Url: https://www.airbnb.com/rooms/19437073
# [Document(id="{ObjectId('67252c67739892c59d794e66')}", metadata={'similarityScore': 0.8543511964710722, 'id': ObjectId('67252c67739892c59d794e66'), 'name': 'Sunny Bungalow with Private Hot Tub Near Downtown', 'location': {'type': 'Point', 'coordinates': [-104.94234, 39.7423]}, 'description': 'This Bungalow-style single-family home is perfect for multi-family parties or roommate situations.  It features 2 full bedrooms plus a loft-style "guest" bedroom, 2 separate kitchens, hardwood floors, theater, covered front porch, natural light, fenced backyard, a hot tub, and a vibrant, hip neighborhood next to City Park and minutes from downtown!  The garden-level bedroom can be closed off into its own studio apartment complete with its own kitchen and bathroom for multifamily parties.', 'neighborhood_overview': "The South City Park / Congress Park Neighborhood is home to quiet residential streets bordered by lively entertainment.  Within walking distance from the house are bars, restaurants, breweries, diners, gyms, yoga studios, salons, coffee shops, retail stores, ice cream parlors, liquor stores, fast food, live music venues, museums, parks, a health food supermarket and a zoo!  The Sprouts Farmer's Market (grocery store) is conveniently located 2 blocks from the house, with a liquor store across the street.", 'price': '', 'amenities': ['Hangers', 'Essentials', 'Dishwasher', 'Dedicated workspace', 'Toaster', 'Barbecue utensils', 'Smoking allowed', 'Microwave', 'Shampoo', 'Hair dryer', 'Oven', 'Baking sheet', 'Dishes and silverware', 'Private hot tub', 'Self check-in', 'Smoke alarm', 'Dining table', '46 inch HDTV with Amazon Prime Video, Netflix, Roku, standard cable', 'Board games', 'Fireplace guards', 'Freezer', 'First aid kit', 'Body soap', 'Carbon monoxide alarm', 'Fire extinguisher', 'Wine glasses', 'Luggage dropoff allowed', 'Outdoor dining area', 'Cleaning products', 'Kitchen', 'Refrigerator', 'Private entrance', 'Clothing storage: walk-in closet, closet, wardrobe, and dresser', 'Cooking basics', 'Extra pillows and blankets', 'Backyard', 'Hot water', 'Coffee maker', 'BBQ grill', 'Free washer – In unit', 'Laundromat nearby', 'Central air conditioning', 'Ceiling fan', 'Window AC unit', 'Free street parking', 'Long term stays allowed', 'Patio or balcony', 'Room-darkening shades', 'Conditioner', 'Outdoor furniture', 'Central heating', 'Iron', 'Hot water kettle', 'Keypad', 'Stove', 'Wifi', 'Bed linens', 'Exterior security cameras on property', 'Free dryer – In unit', 'Bathtub'], 'listing_url': 'https://www.airbnb.com/rooms/20956686'}, page_content='Sunny Bungalow with Private Hot Tub Near Downtown'),
#  Document(id="{ObjectId('67252c67739892c59d7950a9')}", metadata={'similarityScore': 0.8536706479591533, 'id': ObjectId('67252c67739892c59d7950a9'), 'name': '1 Bedroom Suite with Hot Tub', 'location': {'type': 'Point', 'coordinates': [-104.93183, 39.75742]}, 'description': 'A remodeled space in a great Denver neighborhood with a separate and secure keyless entrance.  Just 2 blocks from recently opened café, brew house, wine bar and pizza joint.  If you prefer to stay in, there’s a kitchen, living room, workout space and bath.  Don’t forget you will also have access to the hot tub.  Enjoy a comfortable queen bed and take advantage of the provided coffee to get your day started.  If you have a larger party please inquire about our 2 bedroom suite option.', 'neighborhood_overview': '', 'price': '$117.00', 'amenities': ['Hot tub', 'Hangers', 'Essentials', 'Dishwasher', 'Microwave', 'Shampoo', 'Hair dryer', 'Oven', 'Dishes and silverware', 'Smoke alarm', 'Exercise equipment', 'Carbon monoxide alarm', 'Fire extinguisher', 'Heating', 'Kitchen', 'Gym', 'Refrigerator', 'Private entrance', 'Cooking basics', 'Backyard', 'Hot water', 'Coffee maker', 'Central air conditioning', 'Free street parking', 'Patio or balcony', 'Stainless steel electric stove', 'Iron', 'Wifi', 'Bed linens', 'Exterior security cameras on property', 'TV'], 'listing_url': 'https://www.airbnb.com/rooms/37567133'}, page_content='1 Bedroom Suite with Hot Tub'),
#  Document(id="{ObjectId('67252c67739892c59d7950be')}", metadata={'similarityScore': 0.8501666962901957, 'id': ObjectId('67252c67739892c59d7950be'), 'name': '2 Bedroom Suite with Hot Tub', 'location': {'type': 'Point', 'coordinates': [-104.93039, 39.7582]}, 'description': 'A remodeled space in a great Denver neighborhood with a separate and secure keyless entrance.  Just 2 blocks from recently opened café, brew house, wine bar and pizza joint.  If you prefer to stay in, there’s two bedrooms, a kitchen, living room, workout space and bath.  Don’t forget you will also have access to the hot tub.  Enjoy comfortable queen beds and take advantage of the free coffee to get your day started.  If you have a smaller party please inquire about our 1 bedroom suite option.', 'neighborhood_overview': '', 'price': '$191.00', 'amenities': ['Hot tub', 'Hangers', 'Essentials', 'Dishwasher', 'Microwave', 'Shampoo', 'Hair dryer', 'Oven', 'Dishes and silverware', 'Air conditioning', 'Smoke alarm', 'Carbon monoxide alarm', 'Fire extinguisher', 'Heating', 'Kitchen', 'Gym', 'Refrigerator', 'Private entrance', 'TV with standard cable', 'Cooking basics', 'Extra pillows and blankets', 'Backyard', 'Coffee maker', 'Free street parking', 'Iron', 'Stove', 'Wifi', 'Bed linens', 'Exterior security cameras on property'], 'listing_url': 'https://www.airbnb.com/rooms/38134365'}, page_content='2 Bedroom Suite with Hot Tub'),
#  Document(id="{ObjectId('67252c67739892c59d7950c9')}", metadata={'similarityScore': 0.8419743901414977, 'id': ObjectId('67252c67739892c59d7950c9'), 'name': 'Denver Couples Retreat 2BR, 2 BA Hot Tub Privacy', 'location': {'type': 'Point', 'coordinates': [-104.91975, 39.6578]}, 'description': 'Denver Tech Center Private 2 BR, 2 BA apt & patio!  New Cedar Spa Room.  Fun couples reunion getaway!  Make The Blue Bear Den your base camp for exploring colorful Colorado! Close to sports & entertainment venues. Private entrance to downstairs king & queen bedrooms. Premium cable, & wifi.  Nice kitchenette with full size fridge, sink, dishwasher, & microwave.  Close to RTD Light Rail, & Starbucks. Ranked #1 Neighborhood in Colorado, just off I-25 & Hampden.  Relaxing hot tub room.', 'neighborhood_overview': 'Our Holly Hills neighborhood was ranked #1 in entire state of Colorado by the Denver Post.  Beautiful tree lined streets. We offer a lovely fenced yard around your private entrance and a patio for your enjoyment.', 'price': '$266.00', 'amenities': ['Hangers', 'Essentials', 'Pack ’n play/Travel crib - always at the listing', 'Books and reading material', 'Dishwasher', 'Toaster', 'Barbecue utensils', 'Microwave', 'Shampoo', 'Hair dryer', 'Private backyard – Fully fenced', 'Baking sheet', 'Clothing storage: closet and dresser', 'Dishes and silverware', 'EV charger - level 1', 'Private hot tub', 'Self check-in', 'Noise decibel monitors on property', 'Smoke alarm', 'Blender', 'Portable fans', 'Board games', 'Freezer', 'First aid kit', 'Shower gel', 'Carbon monoxide alarm', 'Fire extinguisher', 'Wine glasses', 'Luggage dropoff allowed', 'Outdoor dining area', 'Cleaning products', 'Suave conditioner', 'Suave body soap', 'Shared patio or balcony', 'Heating', 'Kitchen', 'Fire pit', 'Cleaning available during stay', 'Refrigerator', 'Private entrance', '42 inch HDTV with standard cable', 'Cooking basics', 'Extra pillows and blankets', 'Hot water', 'Coffee maker', 'BBQ grill', 'Free washer – In unit', 'Central air conditioning', 'Free street parking', 'Long term stays allowed', 'Garden view', 'Outdoor furniture', 'Free parking on premises', 'Iron', 'Keypad', 'Indoor fireplace: electric', 'Coffee', 'Folding or convertible high chair', 'Wifi', 'Bed linens', 'Exterior security cameras on property', 'Free dryer – In unit'], 'listing_url': 'https://www.airbnb.com/rooms/38511409'}, page_content='Denver Couples Retreat 2BR, 2 BA Hot Tub Privacy'),
#  Document(id="{ObjectId('67252c67739892c59d794e2b')}", metadata={'similarityScore': 0.8418297673362369, 'id': ObjectId('67252c67739892c59d794e2b'), 'name': 'NEW! 2BR Townhouse, private deck/hot tub/Arcade!', 'location': {'type': 'Point', 'coordinates': [-104.97374, 39.74706]}, 'description': '', 'neighborhood_overview': 'Close to surrounding attractions!', 'price': '$499.00', 'amenities': ['Hangers', 'Essentials', 'Dishwasher', 'Dedicated workspace', 'Barbecue utensils', 'Microwave', 'Shampoo', 'Hair dryer', 'Oven', 'Dishes and silverware', 'Private hot tub', 'City skyline view', 'Self check-in', 'Smoke alarm', 'Mountain view', 'First aid kit', 'Private patio or balcony', 'Fast wifi – 633 Mbps', 'Carbon monoxide alarm', 'Fire extinguisher', 'Game console', 'Heating', 'Kitchen', 'Refrigerator', 'TV with standard cable', 'Cooking basics', 'Extra pillows and blankets', 'Hot water', 'Coffee maker', 'BBQ grill', 'Free washer – In unit', 'Central air conditioning', 'Free street parking', 'Outdoor furniture', 'Free parking on premises', 'Iron', 'Keypad', 'Stove', 'Private entrance', 'Bed linens', 'Free dryer – In unit'], 'listing_url': 'https://www.airbnb.com/rooms/19437073'}, page_content='NEW! 2BR Townhouse, private deck/hot tub/Arcade!')]

# %%
from langchain.prompts import ChatPromptTemplate

REPHRASE_PROMPT = """\
Given the following conversation and a follow up question, rephrase the follow up \
question to be a standalone question.

Chat History:
{chat_history}
Follow Up Input: {question}
Standalone Question:"""

CONTEXT_PROMPT = """\
You are a chatbot, tasked with answering any question about \
rental listings from the context. You can also answer questions about the particular areas, and provide suggestions for things to do.\
You may ask a follow up question about things the user likes to do while on vacation or if there's a particular point of interest.

Generate a response of 100 words or less for the \
given question based solely on the provided search results. \
You must only use information from the provided search results. Use an unbiased and \
fun tone. Do not repeat text. Your response must be solely based on the provided context.

If there is nothing in the context is relevant to the question at hand, just say \
"I'm not sure." Don't try to make up an answer.

Anything between the following `context` html blocks is retrieved from a knowledge \
bank, not part of the conversation with the user. 

<context>
    {context} 
<context/>

REMEMBER: If there is no relevant information within the context, just say "I'm \
not sure." Don't try to make up an answer. Anything between the preceding 'context' \
html blocks is retrieved from a knowledge bank, not part of the conversation with the \
user.\

User Question: {input}

Chatbot Response:"""

rephrase_prompt_template = ChatPromptTemplate.from_template(REPHRASE_PROMPT)
context_prompt_template = ChatPromptTemplate.from_template(CONTEXT_PROMPT)

# %%
# Use a custom retriever
document_retriever = retriever

# Rephrase Chain
rephrase_chain = rephrase_prompt_template | azure_openai_chat
# Context Chain
context_chain = context_prompt_template | azure_openai_chat

# %%
messages = [{"content": "Do you have any houses in quiet neighborhoods?", "role": "user"}]

rephrased_question = rephrase_chain.invoke({"chat_history": messages[:-1], "question": messages[-1]})
print(rephrased_question.content)
# Out:
# What type of neighborhood are you looking for when it comes to houses?

# %%
# Get the context from the database
context = document_retriever.invoke(str(rephrased_question.content))
# Out:
# Similarity Score: 0.8197907805442868
# id: 67252c67739892c59d794fb7
# Name: Cute House in $million neighborhood
# Location: {'type': 'Point', 'coordinates': [-104.95458, 39.68801]}
# Description: Fully furnished, pet friendly fully fenced backyard, quiet professionals neighbourhood of million dollar homes.  Newly renovated. Big screen smart tv for cinema viewing. New fridge heating hot water roof and siding. 10 minutes to Cherry Creek upmarket shopping restaurants and bars, Washington Park activities, DU, Gaylord and Pearl st restaurants, bars, farmers mkt, Wholefoods, Starbucks, fast food. 15minutes to downtown, Single garage, 2 off street parking spaces. Tons of on street parking.
# Neighborhood Overview: Upscale multi-million dollar homes. Quiet, professionals, close to great restaurants, bars and an awesome park with lots to do.
# Price per day: $110.00
# Amenities: ['Hangers', 'Essentials', 'Dishwasher', 'Books and reading material', 'Dedicated workspace', 'Toaster', 'Microwave', 'Oven', 'Baking sheet', 'Dishes and silverware', 'Sun loungers', 'Single level home', 'Ethernet connection', 'Indoor fireplace', 'Smoke alarm', 'Blender', 'Dining table', 'Portable fans', 'Board games', 'Freezer', 'Coffee maker: french press', 'First aid kit', 'Private patio or balcony', 'Body soap', 'Carbon monoxide alarm', 'Fire extinguisher', 'Wine glasses', 'Luggage dropoff allowed', 'Washer', 'Pets allowed', 'Outdoor dining area', 'Cleaning products', 'Clothing storage: closet, wardrobe, and dresser', 'Heating', 'Kitchen', 'Cleaning available during stay', 'Refrigerator', 'Cooking basics', 'Extra pillows and blankets', 'Backyard', 'Bose and Soundbot sound system with Bluetooth and aux', 'Hot water', 'Drying rack for clothing', 'Dryer', 'Free street parking', 'Long term stays allowed', 'Window AC unit', 'Bathtub', 'Room-darkening shades', 'Outdoor furniture', 'Free parking on premises', 'Iron', 'Hot water kettle', 'Coffee', 'Bikes', 'Stove', 'Wifi', 'Bed linens', 'TV']
# Listing Url: https://www.airbnb.com/rooms/30039546
#
# Similarity Score: 0.8065401911735592
# id: 67252c67739892c59d794e07
# Name: The Kaleidoscope House
# Location: {'type': 'Point', 'coordinates': [-105.01573, 39.76154]}
# Description: A colorful and recently updated home built in 1885 features a large relaxing front porch that is 420 friendly.  The vibrant Highlands neighborhood is coming back to life after covid and offers many great restaurants, coffee shops, brewery bars, yoga, all within walking distance.
# Neighborhood Overview:
# Price per day: $90.00
# Amenities: ['Hangers', 'Essentials', 'Dishwasher', 'Toaster', 'Barbecue utensils', 'Microwave', 'Shampoo', 'Hair dryer', 'Dove and homemade  body soap', 'Oven', 'Baking sheet', 'Private backyard – Fully fenced', 'Dishes and silverware', 'Self check-in', 'Piano', 'Smoke alarm', 'Dining table', 'Blender', 'Portable fans', 'Board games', 'Freezer', 'First aid kit', 'Bread maker', 'Carbon monoxide alarm', 'Fire extinguisher', 'Wine glasses', 'Luggage dropoff allowed', 'Outdoor dining area', 'Cleaning products', 'Record player', 'Lockbox', 'HDTV with Roku', 'Heating', 'Kitchen', 'Shared patio or balcony', 'Refrigerator', 'Cooking basics', 'Extra pillows and blankets', 'Sound system', 'Hot water', 'Clothing storage: closet', 'Free washer – In unit', 'Lock on bedroom door', 'Coffee maker', 'Central air conditioning', 'Ceiling fan', 'Free street parking', 'Rice maker', 'Conditioner', 'Outdoor furniture', 'BBQ grill: charcoal, gas', 'Iron', 'Exercise equipment: elliptical', 'Hot water kettle', 'Coffee', 'Stove', 'Wifi', 'Bed linens', 'Free dryer – In unit', 'Bathtub']
# Listing Url: https://www.airbnb.com/rooms/18501266
#
# Similarity Score: 0.8062688823778118
# id: 67252c67739892c59d794e4a
# Name: 2 bedroom, 2 bathroom house near Wash Park
# Location: {'type': 'Point', 'coordinates': [-104.95917, 39.69448]}
# Description: Denver bungalow with remodeled kitchen add-on and Spanish-style backyard in a quiet neighborhood with big trees.  Ideal for a couple/family considering relocation and looking to experience an authentic Denver neighborhood, visiting family, looking for flexibility while buying property, etc.  <br /><br />This house is not a rental, it is our primary residence.  As a result, this is a fully equipped, functioning house, not something hastily assembled to rent. Additional details under House Rules.
# Neighborhood Overview: Old neighborhood in Denver with big trees close to downtown. Walking distance to public library, 20+ tennis courts, 5+ basketball courts, and 165 acre Washington Park, designated one of the "Great Public Spaces in America” by the American Planning Association.
# Price per day:
# Amenities: ['Hangers', 'Essentials', 'Dishwasher', 'Books and reading material', 'Toaster', 'Barbecue utensils', 'Microwave', 'Shampoo', 'Hair dryer', 'Oven', 'Baking sheet', 'Clothing storage: closet and dresser', 'Dishes and silverware', 'Private backyard – Fully fenced', 'Samsung refrigerator', 'Indoor fireplace: gas', 'Self check-in', 'Smoke alarm', 'Dining table', 'Blender', 'Portable fans', 'Board games', 'Freezer', 'First aid kit', 'Private patio or balcony', 'Body soap', 'Portable heater', 'Shower gel', 'Carbon monoxide alarm', 'Fire extinguisher', 'Wine glasses', 'Luggage dropoff allowed', 'Exercise equipment: free weights, yoga mat', 'Outdoor dining area', 'Cleaning products', 'Radiant heating', 'Kitchen', 'Cooking basics', 'Extra pillows and blankets', 'Hot water', 'Drying rack for clothing', 'Coffee maker', 'Free washer – In unit', 'AC - split type ductless system', 'Laundromat nearby', 'BBQ grill', 'Free street parking', 'Ceiling fan', 'Room-darkening shades', '46 inch HDTV', 'Conditioner', 'Outdoor furniture', 'Iron', 'Hot water kettle', 'Keypad', 'Coffee', 'Stove', 'Wifi', 'Bed linens', 'Free dryer – In unit', 'Bathtub']
# Listing Url: https://www.airbnb.com/rooms/20213812
#
# Similarity Score: 0.8059080358798497
# id: 67252c67739892c59d794cac
# Name: Cozy 1BD-parking, yard, laundry
# Location: {'type': 'Point', 'coordinates': [-104.91961, 39.73839]}
# Description: Mother-in-law suite with off-street parking and separate entrance. Full kitchen, dishwasher, stove and oven. Enjoy the patio, walk to the bars and restaurants in my neighborhood, or drive 10 minutes to downtown.
# Neighborhood Overview: This neighborhood is perfect for someone who wants to be close to the city, but not have to worry about noise, traffic, or parking. There's plenty of walkable shops, bars, and restaurants. The best part is there are two grocery stores and a liquor store just 1 block away. <br />My house is 15 minutes from downtown, and 30 minutes from the airport, in a residential neighborhood called Montclair. There are some excellent coffee shops, restaurants, and bars within walking distance. 2 grocery stores are just a block away. There's a park a few blocks south of me with a playground for those of you with kids. <br />**Check out my "guidebook" for my recommended restaurants/bars/cafes!
# Price per day: $115.00
# Amenities: ['Hangers', 'Essentials', 'Dishwasher', 'Microwave', 'Shampoo', 'Hair dryer', 'Oven', 'Dishes and silverware', 'Babysitter recommendations', 'Shared backyard – Fully fenced', 'Smoke alarm', 'First aid kit', 'Carbon monoxide alarm', 'Fire extinguisher', 'Fast wifi – 133 Mbps', 'Shared patio or balcony', 'Heating', 'Kitchen', 'Refrigerator', 'Cooking basics', 'Extra pillows and blankets', 'Hot water', 'Coffee maker', 'BBQ grill', 'Dryer', 'Free street parking', 'Long term stays allowed', 'Bathtub', 'Free parking on premises', 'Free washer – In building', 'Iron', 'Stove', 'Private entrance', 'Bed linens', 'Exterior security cameras on property', 'TV']
# Listing Url: https://www.airbnb.com/rooms/5508545
#
# Similarity Score: 0.8044855594635066
# id: 67252c67739892c59d794e9e
# Name: Hillcrest Manor-Mid Century Modern 1963 Art House
# Location: {'type': 'Point', 'coordinates': [-104.91544, 39.64702]}
# Description: This beautifully unique mid-century modern gem promises an unparalleled living experience during your stay. Prepare to be wowed by the fantastic features that await you: 🍽️ Chefs Kitchen; 🛁 Luxury Master Bath/Suite; Ample Space: Accommodate your family, friends, or establish a productive workspace with 3 additional bedrooms and 1 office. The 3 bathrooms ensure convenience for everyone; 🌳 Large Fenced-in Yard; 🔥 Entertaining Patio with Firepit.
# Neighborhood Overview: This South Denver neighborhood you are in called Southmoor Park built in in 1963. Yes, we are in Denver. I love this neighborhood because everything you could want is less than a mile. Super Target, Wholefoods, Walmart, King Supers (grocery stores).<br />I love it because you still get the urban city suburb vibe. Families, young and old. Very diverse.
# Price per day: $350.00
# Amenities: ['Hangers', 'Essentials', 'Dishwasher', 'Dedicated workspace', 'Fast wifi – 434 Mbps', 'Microwave', 'Shampoo', 'Hair dryer', 'Oven', 'Baby safety gates', 'Dishes and silverware', 'Babysitter recommendations', 'Shared backyard – Fully fenced', 'Self check-in', 'Noise decibel monitors on property', 'Indoor fireplace: wood-burning', 'Smoke alarm', 'Clothing storage', 'Fireplace guards', 'Smart lock', 'Crib', 'Outlet covers', 'First aid kit', 'Body soap', 'Outdoor kitchen', 'Carbon monoxide alarm', 'Fire extinguisher', 'Pets allowed', 'TV with Apple TV, Hulu, Netflix', 'Outdoor dining area', 'Heating', 'Kitchen', 'Fire pit', 'Cleaning available during stay', 'Refrigerator', 'Cooking basics', 'Extra pillows and blankets', 'Sound system', 'Hot water', 'KitchenAid stainless steel gas stove', 'Coffee maker', 'BBQ grill', 'Central air conditioning', 'Free street parking', 'Long term stays allowed', 'Patio or balcony', 'Room-darkening shades', 'Conditioner', 'Outdoor furniture', 'Free parking on premises', 'Iron', 'Pack ’n play/Travel crib', 'Private entrance', 'Bed linens', 'Exterior security cameras on property', 'Bathtub']
# Listing Url: https://www.airbnb.com/rooms/22209112

# %%
# Generate a response based on the context
response = context_chain.invoke({"context": context, "input": rephrased_question.content})
print(response.content)
# Out:
# Here are a few rental listings located in quiet neighborhoods:
# - 17th & Larimer Private, Quiet Condo - $113.00/night
# - Beautifully Renovated 1 bedroom in Quiet Community - $55.00/night
# - Cute House in $million neighborhood - $110.00/night
# - Cozy 1BD-parking, yard, laundry - $115.00/night

# %%
messages.append({"content": response.content, "role": "assistant"})

# %%
# Test with another question to see if the chat history is maintained
messages.append({"content": "Which rental listings are quiet?", "role": "user"})

rephrased_question = rephrase_chain.invoke({"chat_history": messages[:-1], "question": messages[-1]})
context = document_retriever.invoke(str(rephrased_question.content))

response = context_chain.invoke({"context": context, "input": rephrased_question.content})
# Out:
# Similarity Score: 0.8145037889480649
# id: 67252c67739892c59d794d43
# Name: 17th & Larimer Private, Quiet Condo
# Location: {'type': 'Point', 'coordinates': [-104.99687, 39.74981]}
# Description: This condo is a QUIET building, still close to everything in downtown Denver! Walk to 16th Street Mall, Coors Field, Theater District, Pepsi Center, and more than 100 restaurants - then retire to your own personal space for rest & relaxation...<br /><br />30-night minimum stay, and we are required to sign a simple lease agreement to be kept on file with HOA.
# Neighborhood Overview:
# Price per day: $113.00
# Amenities: ['Hangers', 'Essentials', 'Children’s books and toys for ages 5-10 years old and 10+ years old', 'Books and reading material', 'Dedicated workspace', 'Bluetooth sound system', 'Dishwasher', 'Microwave', 'Toaster', 'Barbecue utensils', 'Shampoo', 'Hair dryer', 'Free parking garage on premises – 1 space', 'Oven', 'Baking sheet', 'Shared sauna', 'Dishes and silverware', 'Host greets you', 'City skyline view', 'Ethernet connection', 'Pool table', 'Shared BBQ grill: gas', 'Piano', 'Indoor fireplace: wood-burning', 'Smoke alarm', 'Board games', 'Freezer', 'First aid kit', 'Private patio or balcony', 'Body soap', 'Shower gel', 'Carbon monoxide alarm', 'Fire extinguisher', 'Wine glasses', 'Elevator', 'Outdoor dining area', 'Cleaning products', 'Clothing storage: closet, wardrobe, and dresser', 'Safe', 'Kitchen', 'Fire pit', 'Cleaning available during stay', 'Refrigerator', 'Shared gym in building', 'TV with standard cable', 'Cooking basics', 'Extra pillows and blankets', 'Exercise equipment: elliptical, free weights, stationary bike, treadmill, yoga mat, workout bench, rowing', 'Hot water', 'Coffee maker', 'Free washer – In unit', 'Central air conditioning', 'Long term stays allowed', 'Conditioner', 'Outdoor furniture', 'Central heating', 'Iron', 'Coffee', 'Stove', 'Wifi', 'Paid street parking off premises', 'Bed linens', 'Free dryer – In unit', 'Bathtub']
# Listing Url: https://www.airbnb.com/rooms/12681403
#
# Similarity Score: 0.8127422555992299
# id: 67252c67739892c59d794fa8
# Name: Beautifully Renovated 1 bedroom in Quiet Community
# Location: {'type': 'Point', 'coordinates': [-104.93204, 39.73306]}
# Description: This is a great rental for frequent travelers, new arrivals, or singles or couples who want the convenience of a fully furnished unit. <br />The neighborhood is quiet and residential, and has several grocery and convenience stores nearby. Wifi and 55" "smart" TV included. <br />Security building with large common area - gym and two pools - one outdoor and one in your building. The gym has machines and free weights, with wall-mounted TVs so you won't miss the news.
# Neighborhood Overview: Quiet, residential neighborhood with a park across the street. Rose Medical Center is one block away.
# Price per day: $55.00
# Amenities: ['Hangers', 'Essentials', 'Dedicated workspace', 'Microwave', 'Hair dryer', 'Oven', 'Dishes and silverware', 'Air conditioning', 'Smoke alarm', 'Private patio or balcony', 'Elevator', 'Washer', 'Outdoor dining area', 'Heating', 'Kitchen', 'Gym', 'Refrigerator', 'Cooking basics', 'Shared pool', 'Coffee maker', 'Hot water', 'BBQ grill', 'Dryer', 'Free street parking', 'Wifi', 'Outdoor furniture', 'Free parking on premises', 'Private entrance', 'TV']
# Listing Url: https://www.airbnb.com/rooms/29507708
#
# Similarity Score: 0.811555743217474
# id: 67252c67739892c59d794fb7
# Name: Cute House in $million neighborhood
# Location: {'type': 'Point', 'coordinates': [-104.95458, 39.68801]}
# Description: Fully furnished, pet friendly fully fenced backyard, quiet professionals neighbourhood of million dollar homes.  Newly renovated. Big screen smart tv for cinema viewing. New fridge heating hot water roof and siding. 10 minutes to Cherry Creek upmarket shopping restaurants and bars, Washington Park activities, DU, Gaylord and Pearl st restaurants, bars, farmers mkt, Wholefoods, Starbucks, fast food. 15minutes to downtown, Single garage, 2 off street parking spaces. Tons of on street parking.
# Neighborhood Overview: Upscale multi-million dollar homes. Quiet, professionals, close to great restaurants, bars and an awesome park with lots to do.
# Price per day: $110.00
# Amenities: ['Hangers', 'Essentials', 'Dishwasher', 'Books and reading material', 'Dedicated workspace', 'Toaster', 'Microwave', 'Oven', 'Baking sheet', 'Dishes and silverware', 'Sun loungers', 'Single level home', 'Ethernet connection', 'Indoor fireplace', 'Smoke alarm', 'Blender', 'Dining table', 'Portable fans', 'Board games', 'Freezer', 'Coffee maker: french press', 'First aid kit', 'Private patio or balcony', 'Body soap', 'Carbon monoxide alarm', 'Fire extinguisher', 'Wine glasses', 'Luggage dropoff allowed', 'Washer', 'Pets allowed', 'Outdoor dining area', 'Cleaning products', 'Clothing storage: closet, wardrobe, and dresser', 'Heating', 'Kitchen', 'Cleaning available during stay', 'Refrigerator', 'Cooking basics', 'Extra pillows and blankets', 'Backyard', 'Bose and Soundbot sound system with Bluetooth and aux', 'Hot water', 'Drying rack for clothing', 'Dryer', 'Free street parking', 'Long term stays allowed', 'Window AC unit', 'Bathtub', 'Room-darkening shades', 'Outdoor furniture', 'Free parking on premises', 'Iron', 'Hot water kettle', 'Coffee', 'Bikes', 'Stove', 'Wifi', 'Bed linens', 'TV']
# Listing Url: https://www.airbnb.com/rooms/30039546
#
# Similarity Score: 0.8103009575426022
# id: 67252c67739892c59d794cac
# Name: Cozy 1BD-parking, yard, laundry
# Location: {'type': 'Point', 'coordinates': [-104.91961, 39.73839]}
# Description: Mother-in-law suite with off-street parking and separate entrance. Full kitchen, dishwasher, stove and oven. Enjoy the patio, walk to the bars and restaurants in my neighborhood, or drive 10 minutes to downtown.
# Neighborhood Overview: This neighborhood is perfect for someone who wants to be close to the city, but not have to worry about noise, traffic, or parking. There's plenty of walkable shops, bars, and restaurants. The best part is there are two grocery stores and a liquor store just 1 block away. <br />My house is 15 minutes from downtown, and 30 minutes from the airport, in a residential neighborhood called Montclair. There are some excellent coffee shops, restaurants, and bars within walking distance. 2 grocery stores are just a block away. There's a park a few blocks south of me with a playground for those of you with kids. <br />**Check out my "guidebook" for my recommended restaurants/bars/cafes!
# Price per day: $115.00
# Amenities: ['Hangers', 'Essentials', 'Dishwasher', 'Microwave', 'Shampoo', 'Hair dryer', 'Oven', 'Dishes and silverware', 'Babysitter recommendations', 'Shared backyard – Fully fenced', 'Smoke alarm', 'First aid kit', 'Carbon monoxide alarm', 'Fire extinguisher', 'Fast wifi – 133 Mbps', 'Shared patio or balcony', 'Heating', 'Kitchen', 'Refrigerator', 'Cooking basics', 'Extra pillows and blankets', 'Hot water', 'Coffee maker', 'BBQ grill', 'Dryer', 'Free street parking', 'Long term stays allowed', 'Bathtub', 'Free parking on premises', 'Free washer – In building', 'Iron', 'Stove', 'Private entrance', 'Bed linens', 'Exterior security cameras on property', 'TV']
# Listing Url: https://www.airbnb.com/rooms/5508545
#
# Similarity Score: 0.8081166148185788
# id: 67252c67739892c59d794d69
# Name: Welcome to your quiet apartment in our house!
# Location: {'type': 'Point', 'coordinates': [-104.95397, 39.75788]}
# Description: Your well appointed full apartment in the lower level of our house, a very quiet neighborhood just minutes to downtown.  National Western Complex, aquarium, zoo, stadiums, convention center, science museum, parks and golf courses in very close proximity.  Easy access to light rail and bus, abundant street parking available 24/7.  Large back yard with grill and covered patio.  Safe neighborhood in central Denver.  No smoking and no 420/marijuana on property.
# Neighborhood Overview: The neighborhood is very quiet.  Very little vehicle traffic yet close to everything fun in Denver.  Easy access to downtown, museums, parks, botanic gardens, stadiums, national western complex and more.  Several public golf courses in walking distance.
# Price per day: $91.00
# Amenities: ['Hangers', 'Essentials', 'Dishwasher', 'Books and reading material', 'Toaster', 'Barbecue utensils', 'Children’s dinnerware', 'Microwave', 'Shampoo', 'Hair dryer', 'Oven', 'Baking sheet', 'Private backyard – Fully fenced', 'Dishes and silverware', 'Babysitter recommendations', 'Ethernet connection', 'Air conditioning', 'Self check-in', 'Smoke alarm', 'Portable fans', 'Board games', 'Freezer', 'Crib', 'First aid kit', 'Shower gel', 'Carbon monoxide alarm', 'Fire extinguisher', 'Wine glasses', 'Baby bath', 'Luggage dropoff allowed', 'Washer', 'Pets allowed', 'Outdoor dining area', 'Cleaning products', 'Shared patio or balcony', 'Heating', 'Kitchen', 'Fire pit', 'Refrigerator', 'Private entrance', 'TV with standard cable', 'Cooking basics', 'Extra pillows and blankets', 'Hot water', 'Coffee maker', 'BBQ grill', 'Dryer', 'Free street parking', 'Long term stays allowed', 'High chair', 'Outdoor furniture', 'Free parking on premises', 'Iron', 'Keypad', 'Coffee', 'Pack ’n play/Travel crib', 'Children’s books and toys', 'Stove', 'Wifi', 'Bed linens']
# Listing Url: https://www.airbnb.com/rooms/13745963

# %%
print("Rephrased Question: ", rephrased_question.content)
print("LLM Response: ", response.content)
# Out:
# Rephrased Question:  Can you provide me with a list of rental listings that are located in quiet neighborhoods?
# LLM Response:  Here are some rental listings located in quiet neighborhoods: 17th & Larimer Private, Quiet Condo ($113.00), Beautifully Renovated 1 bedroom in Quiet Community ($55.00), Cute House in $million neighborhood ($110.00), and Cozy 1BD-parking, yard, laundry ($115.00).
